# %%
import skrf
hp=skrf.Network('85058B_FLBLOAD_8510C_mate1_swp2.s1p')
ff=skrf.Network('85058B_FLBLOAD_FieldFox_mate1_swp2.s1p')

# %%
hp
# Out:
# 1-Port Network: '85058B_FLBLOAD_8510C_mate1_swp2',  45000000.0-50000000000.0 Hz, 10001 pts, z0=[50.+0.j]

# %%
ff
# Out:
# 1-Port Network: '85058B_FLBLOAD_FieldFox_mate1_swp2',  300000.0-50000000000.0 Hz, 10001 pts, z0=[50.+0.j]

# %%
net = skrf.Network('85058B_FSHORT1_8510C_mate1_swp2.s1p')
net.plot_s_deg_unwrap()

# %%
m=skrf.media.DefinedGammaZ0(skrf.Frequency(1e9,2e9,101,unit='Hz'), z0=50)
m.thru().s
# Out:
# array([[[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
#         [1.+0.j, 0.+0.j]],
#
#        [[0.+0.j, 1.+0.j],
# ...
